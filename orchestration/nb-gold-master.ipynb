# %%
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/003-gold/nb-gold-dim",1800,)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/003-gold/nb-gold-fact",1800)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/003-gold/nb-master_cube",1800)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/003-gold/nb-gold-kpi",1800)
