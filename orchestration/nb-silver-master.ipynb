# %%
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/002-silver/nb-silver-accounts",1800)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/002-silver/nb-silver-company",1800)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/002-silver/nb-silver-department",1800)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/002-silver/nb-silver-employee",1800)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/002-silver/nb-silver-general-lergers",1800)
dbutils.notebook.run("/Workspace/Users/udaykumarpalaka4@gmail.com/P-L-Worforce-analysis-project/002-silver/nb-silver-payroll",1800)
